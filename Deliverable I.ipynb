# %%
#load pandas

import pandas as pd

# %%
#read files

gitCloudRepo='https://github.com/Drops-of-Jupyter/PUBPOL542/raw/main/'
fileName1='distribution-human-rights-vdem.csv'
fileName2='infectious-disease-death-rates.csv'
fileName3='water-and-sanitation.csv'
humrightscsv=pd.read_csv(gitCloudRepo + fileName1)
infdeathscsv=pd.read_csv(gitCloudRepo + fileName2)
sanitationcsv=pd.read_csv(gitCloudRepo + fileName3)

# %%
humrightscsv.head()
# Out:
#         Entity Code  Year  civ_libs_vdem_owid region
# 0  Afghanistan  AFG  1789               0.122   Asia
# 1  Afghanistan  AFG  1790               0.122   Asia
# 2  Afghanistan  AFG  1791               0.122   Asia
# 3  Afghanistan  AFG  1792               0.122   Asia
# 4  Afghanistan  AFG  1793               0.122   Asia

# %%
humrightscsv.shape
# Out:
# (33626, 5)

# %%
infdeathscsv.head()
# Out:
#         Entity Code  Year  \
# 0  Afghanistan  AFG  1990
# 1  Afghanistan  AFG  1991
# 2  Afghanistan  AFG  1992
# 3  Afghanistan  AFG  1993
# 4  Afghanistan  AFG  1994
#
#    Deaths - Infectious diseases - OWID - Sex: Both - Age: Age-standardized (Rate)
# 0                                             394.42
# 1                                             368.78
# 2                                             346.83
# 3                                             350.51
# 4                                             361.07

# %%
infdeathscsv.shape
# Out:
# (6840, 4)

# %%
sanitationcsv.head()
# Out:
#    Access to improved drinking water  Access to basic drinking water  \
# 0                              31.83                           28.17
# 1                              31.86                           28.20
# 2                              34.19                           30.24
# 3                              36.51                           32.27
# 4                              38.85                           34.33
#
#    Access to limited drinking water  Access to unimproved drinking water  \
# 0                              3.66                                43.18
# 1                              3.66                                43.17
# 2                              3.95                                41.69
# 3                              4.24                                40.21
# 4                              4.52                                38.72
#
#    No access to drinking water  Access to safely managed drinking water  \
# 0                        24.99                                    10.93
# 1                        24.97                                    10.94
# 2                        24.12                                    11.73
# 3                        23.28                                    12.51
# 4                        22.42                                    13.31
#
#    Access to improved sanitation  Access to basic sanitation services  \
# 0                          27.52                                21.87
# 1                          27.54                                21.88
# 2                          29.27                                23.27
# 3                          31.01                                24.67
# 4                          32.76                                26.07
#
#    Access to limited sanitation services  \
# 0                                   5.65
# 1                                   5.66
# 2                                   6.00
# 3                                   6.34
# 4                                   6.69
#
#    Access to unimproved sanitation facilities  ...  wat_bas_without  \
# 0                                       46.68  ...            71.83
# 1                                       46.68  ...            71.80
# 2                                       45.74  ...            69.76
# 3                                       44.81  ...            67.73
# 4                                       43.87  ...            65.67
#
#    wat_sm_without  san_imp_number_without  san_bas_number_without  \
# 0           89.07              15061452.0              16235214.0
# 1           89.06              15656386.0              16879101.0
# 2           88.27              15984867.0              17340626.0
# 3           87.49              16338160.0              17839408.0
# 4           86.69              16627222.0              18281012.0
#
#    san_sm_number_without  san_imp_without  san_bas_without  san_sm_without  \
# 0                    NaN            72.48            78.13             NaN
# 1                    NaN            72.46            78.12             NaN
# 2                    NaN            70.73            76.73             NaN
# 3                    NaN            68.99            75.33             NaN
# 4                    NaN            67.24            73.93             NaN
#
#    hyg_bas_number_without  hyg_bas_without
# 0                     NaN              NaN
# 1                     NaN              NaN
# 2                     NaN              NaN
# 3                     NaN              NaN
# 4                     NaN              NaN
#
# [5 rows x 118 columns]

# %%
sanitationcsv.columns[sanitationcsv.columns.str.contains('tity')]
# Out:
# Index(['Entity'], dtype='object')

# %%
# Human rights dataset
# Remove unneeded columns

humrightscsv.columns
bye=[1,4]
humrightscsv.drop(columns=humrightscsv.columns[bye],inplace=True)
humrightscsv.columns
# Out:
# Index(['Entity', 'Year', 'civ_libs_vdem_owid'], dtype='object')

# %%
# Filter rows to years 2015 - 2019

humrightscsv = humrightscsv[(humrightscsv['Year'] >= 2015) & (humrightscsv['Year'] <= 2019)]
humrightscsv.head()
# Out:
#           Entity  Year  civ_libs_vdem_owid
# 226  Afghanistan  2015               0.555
# 227  Afghanistan  2016               0.513
# 228  Afghanistan  2017               0.545
# 229  Afghanistan  2018               0.557
# 230  Afghanistan  2019               0.516

# %%
# Rename columns

humrightscsv.columns.str.replace(pat="civ_libs_vdem_owid", 
                                 repl="VDEM", 
                                 regex=False)
humrightscsv.columns=humrightscsv.columns.str.replace("civ_libs_vdem_owid",
                                                      "VDEM",
                                                      regex=False)
humrightscsv.columns
# Out:
# Index(['Entity', 'Year', 'VDEM'], dtype='object')

# %%
humrightscsv.columns.str.replace(pat="Entity", 
                                 repl="Country", 
                                 regex=False)
humrightscsv.columns=humrightscsv.columns.str.replace("Entity",
                                                      "Country",
                                                      regex=False)

# %%
# Reset index
humrightscsv=humrightscsv.reset_index(drop=True)
humrightscsv.head()
# Out:
#        Country  Year   VDEM
# 0  Afghanistan  2015  0.555
# 1  Afghanistan  2016  0.513
# 2  Afghanistan  2017  0.545
# 3  Afghanistan  2018  0.557
# 4  Afghanistan  2019  0.516

# %%
humrightscsv.iloc[:,:2]
# Out:
#          Country  Year
# 0    Afghanistan  2015
# 1    Afghanistan  2016
# 2    Afghanistan  2017
# 3    Afghanistan  2018
# 4    Afghanistan  2019
# ..           ...   ...
# 925     Zimbabwe  2015
# 926     Zimbabwe  2016
# 927     Zimbabwe  2017
# 928     Zimbabwe  2018
# 929     Zimbabwe  2019
#
# [930 rows x 2 columns]

# %%
# Sanitations dataset
sanitationcsv.head()
# Out:
#    Access to improved drinking water  Access to basic drinking water  \
# 0                              31.83                           28.17
# 1                              31.86                           28.20
# 2                              34.19                           30.24
# 3                              36.51                           32.27
# 4                              38.85                           34.33
#
#    Access to limited drinking water  Access to unimproved drinking water  \
# 0                              3.66                                43.18
# 1                              3.66                                43.17
# 2                              3.95                                41.69
# 3                              4.24                                40.21
# 4                              4.52                                38.72
#
#    No access to drinking water  Access to safely managed drinking water  \
# 0                        24.99                                    10.93
# 1                        24.97                                    10.94
# 2                        24.12                                    11.73
# 3                        23.28                                    12.51
# 4                        22.42                                    13.31
#
#    Access to improved sanitation  Access to basic sanitation services  \
# 0                          27.52                                21.87
# 1                          27.54                                21.88
# 2                          29.27                                23.27
# 3                          31.01                                24.67
# 4                          32.76                                26.07
#
#    Access to limited sanitation services  \
# 0                                   5.65
# 1                                   5.66
# 2                                   6.00
# 3                                   6.34
# 4                                   6.69
#
#    Access to unimproved sanitation facilities  ...  wat_bas_without  \
# 0                                       46.68  ...            71.83
# 1                                       46.68  ...            71.80
# 2                                       45.74  ...            69.76
# 3                                       44.81  ...            67.73
# 4                                       43.87  ...            65.67
#
#    wat_sm_without  san_imp_number_without  san_bas_number_without  \
# 0           89.07              15061452.0              16235214.0
# 1           89.06              15656386.0              16879101.0
# 2           88.27              15984867.0              17340626.0
# 3           87.49              16338160.0              17839408.0
# 4           86.69              16627222.0              18281012.0
#
#    san_sm_number_without  san_imp_without  san_bas_without  san_sm_without  \
# 0                    NaN            72.48            78.13             NaN
# 1                    NaN            72.46            78.12             NaN
# 2                    NaN            70.73            76.73             NaN
# 3                    NaN            68.99            75.33             NaN
# 4                    NaN            67.24            73.93             NaN
#
#    hyg_bas_number_without  hyg_bas_without
# 0                     NaN              NaN
# 1                     NaN              NaN
# 2                     NaN              NaN
# 3                     NaN              NaN
# 4                     NaN              NaN
#
# [5 rows x 118 columns]

# %%
# Keep needed columns

sanitationcsv = sanitationcsv[[
    'Entity',
    'Year',
    'Access to limited drinking water',
    'Access to limited sanitation services',
]]

# %%
sanitationcsv.head()
# Out:
#         Entity  Year  Access to limited drinking water  \
# 0  Afghanistan  2000                              3.66
# 1  Afghanistan  2001                              3.66
# 2  Afghanistan  2002                              3.95
# 3  Afghanistan  2003                              4.24
# 4  Afghanistan  2004                              4.52
#
#    Access to limited sanitation services
# 0                                   5.65
# 1                                   5.66
# 2                                   6.00
# 3                                   6.34
# 4                                   6.69

# %%
# Filter rows to years 2015 - 2019

sanitationcsv = sanitationcsv[(sanitationcsv['Year'] >= 2015) & (sanitationcsv['Year'] <= 2019)]
sanitationcsv.head()
# Out:
#          Entity  Year  Access to limited drinking water  \
# 15  Afghanistan  2015                              3.51
# 16  Afghanistan  2016                              3.16
# 17  Afghanistan  2017                              2.78
# 18  Afghanistan  2018                              2.36
# 19  Afghanistan  2019                              1.91
#
#     Access to limited sanitation services
# 15                                   9.73
# 16                                   9.95
# 17                                  10.18
# 18                                  10.39
# 19                                  10.60

# %%
# Reset index

sanitationcsv=sanitationcsv.reset_index(drop=True)
sanitationcsv.head()
# Out:
#         Entity  Year  Access to limited drinking water  \
# 0  Afghanistan  2015                              3.51
# 1  Afghanistan  2016                              3.16
# 2  Afghanistan  2017                              2.78
# 3  Afghanistan  2018                              2.36
# 4  Afghanistan  2019                              1.91
#
#    Access to limited sanitation services
# 0                                   9.73
# 1                                   9.95
# 2                                  10.18
# 3                                  10.39
# 4                                  10.60

# %%
# Rename columns

sanitationcsv.columns.str.replace(pat="Access to limited drinking water", 
                                  repl="LDW", 
                                  regex=False)
sanitationcsv.columns=sanitationcsv.columns.str.replace("Access to limited drinking water",
                                                        "LDW",
                                                        regex=False)

# %%
sanitationcsv.columns.str.replace(pat="Access to limited sanitation services", 
                                  repl="LSS", 
                                  regex=False)
sanitationcsv.columns=sanitationcsv.columns.str.replace("Access to limited sanitation services",
                                                        "LSS",
                                                        regex=False)

# %%
sanitationcsv.columns.str.replace(pat="Entity", 
                                  repl="Country", 
                                  regex=False)
sanitationcsv.columns=sanitationcsv.columns.str.replace("Entity",
                                                        "Country",
                                                        regex=False)

# %%
sanitationcsv.head()
# Out:
#        Country  Year   LDW    LSS
# 0  Afghanistan  2015  3.51   9.73
# 1  Afghanistan  2016  3.16   9.95
# 2  Afghanistan  2017  2.78  10.18
# 3  Afghanistan  2018  2.36  10.39
# 4  Afghanistan  2019  1.91  10.60

# %%
sanitationcsv.iloc[:,:2]
# Out:
#           Country  Year
# 0     Afghanistan  2015
# 1     Afghanistan  2016
# 2     Afghanistan  2017
# 3     Afghanistan  2018
# 4     Afghanistan  2019
# ...           ...   ...
# 1206     Zimbabwe  2015
# 1207     Zimbabwe  2016
# 1208     Zimbabwe  2017
# 1209     Zimbabwe  2018
# 1210     Zimbabwe  2019
#
# [1211 rows x 2 columns]

# %%
infdeathscsv.head()
# Out:
#         Entity Code  Year  \
# 0  Afghanistan  AFG  1990
# 1  Afghanistan  AFG  1991
# 2  Afghanistan  AFG  1992
# 3  Afghanistan  AFG  1993
# 4  Afghanistan  AFG  1994
#
#    Deaths - Infectious diseases - OWID - Sex: Both - Age: Age-standardized (Rate)
# 0                                             394.42
# 1                                             368.78
# 2                                             346.83
# 3                                             350.51
# 4                                             361.07

# %%
# Filter rows to years 2015 - 2019

infdeathscsv = infdeathscsv[(infdeathscsv['Year'] >= 2015) & (infdeathscsv['Year'] <= 2019)]
infdeathscsv.head()
# Out:
#          Entity Code  Year  \
# 25  Afghanistan  AFG  2015
# 26  Afghanistan  AFG  2016
# 27  Afghanistan  AFG  2017
# 28  Afghanistan  AFG  2018
# 29  Afghanistan  AFG  2019
#
#     Deaths - Infectious diseases - OWID - Sex: Both - Age: Age-standardized (Rate)
# 25                                             164.90
# 26                                             158.93
# 27                                             152.43
# 28                                             146.83
# 29                                             140.37

# %%
# Remove unneeded columns

infdeathscsv.columns
bye=[1]
infdeathscsv.drop(columns=infdeathscsv.columns[bye],inplace=True)
infdeathscsv.columns
# Out:
# Index(['Entity', 'Year',
#        'Deaths - Infectious diseases - OWID - Sex: Both - Age: Age-standardized (Rate)'],
#       dtype='object')

# %%
# Rename columns

infdeathscsv.columns.str.replace(pat="Deaths - Infectious diseases - OWID - Sex: Both - Age: Age-standardized (Rate)", 
                                 repl="Death Rate", 
                                 regex=False)
# Out:
# Index(['Entity', 'Year', 'Death Rate'], dtype='object')

# %%
infdeathscsv.columns=infdeathscsv.columns.str.replace("Deaths - Infectious diseases - OWID - Sex: Both - Age: Age-standardized (Rate)",
                                                      "Death Rate",
                                                      regex=False)

# %%
infdeathscsv.columns.str.replace(pat="Entity", 
                                 repl="Country", 
                                 regex=False)
infdeathscsv.columns=infdeathscsv.columns.str.replace("Entity",
                                                      "Country",
                                                      regex=False)

# %%
infdeathscsv.columns
# Out:
# Index(['Country', 'Year', 'Death Rate'], dtype='object')

# %%
# Reset index

infdeathscsv=infdeathscsv.reset_index(drop=True)
infdeathscsv.head()
# Out:
#        Country  Year  Death Rate
# 0  Afghanistan  2015      164.90
# 1  Afghanistan  2016      158.93
# 2  Afghanistan  2017      152.43
# 3  Afghanistan  2018      146.83
# 4  Afghanistan  2019      140.37

# %%
" Afghanistan ".strip()
# Out:
# 'Afghanistan'

# %%
infdeathscsv.columns.str.lower()
infdeathscsv.columns=infdeathscsv.columns.str.lower()

# %%
sanitationcsv.columns.str.lower()
sanitationcsv.columns=sanitationcsv.columns.str.lower()

# %%
humrightscsv.columns.str.lower()
humrightscsv.columns=humrightscsv.columns.str.lower()

# %%
humrightscsv.head()
# Out:
#        country  year   vdem
# 0  Afghanistan  2015  0.555
# 1  Afghanistan  2016  0.513
# 2  Afghanistan  2017  0.545
# 3  Afghanistan  2018  0.557
# 4  Afghanistan  2019  0.516

# %%
infdeathscsv.head()
# Out:
#        country  year  death rate
# 0  Afghanistan  2015      164.90
# 1  Afghanistan  2016      158.93
# 2  Afghanistan  2017      152.43
# 3  Afghanistan  2018      146.83
# 4  Afghanistan  2019      140.37

# %%
infdeathscsv.iloc[:,:2]
# Out:
#           country  year
# 0     Afghanistan  2015
# 1     Afghanistan  2016
# 2     Afghanistan  2017
# 3     Afghanistan  2018
# 4     Afghanistan  2019
# ...           ...   ...
# 1135     Zimbabwe  2015
# 1136     Zimbabwe  2016
# 1137     Zimbabwe  2017
# 1138     Zimbabwe  2018
# 1139     Zimbabwe  2019
#
# [1140 rows x 2 columns]

# %%
sanitationcsv.iloc[:,:2]
# Out:
#           country  year
# 0     Afghanistan  2015
# 1     Afghanistan  2016
# 2     Afghanistan  2017
# 3     Afghanistan  2018
# 4     Afghanistan  2019
# ...           ...   ...
# 1206     Zimbabwe  2015
# 1207     Zimbabwe  2016
# 1208     Zimbabwe  2017
# 1209     Zimbabwe  2018
# 1210     Zimbabwe  2019
#
# [1211 rows x 2 columns]

# %%
infdeathscsv.iloc[:,1]
# Out:
# 0       2015
# 1       2016
# 2       2017
# 3       2018
# 4       2019
#         ...
# 1135    2015
# 1136    2016
# 1137    2017
# 1138    2018
# 1139    2019
# Name: year, Length: 1140, dtype: int64

# %%
infdeathscsv.year.value_counts()
# Out:
# 2015    228
# 2016    228
# 2017    228
# 2018    228
# 2019    228
# Name: year, dtype: int64

# %%
infdeathscsv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1140 entries, 0 to 1139
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   country     1140 non-null   object
#  1   year        1140 non-null   int64
#  2   death rate  1140 non-null   float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 26.8+ KB

# %%
sanitationcsv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1211 entries, 0 to 1210
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   country  1211 non-null   object
#  1   year     1211 non-null   int64
#  2   ldw      1203 non-null   float64
#  3   lss      1182 non-null   float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 38.0+ KB

# %%
humrightscsv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 930 entries, 0 to 929
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   country  930 non-null    object
#  1   year     930 non-null    int64
#  2   vdem     930 non-null    float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 21.9+ KB

# %%
###ATTEMPTING TO MERGE

infdeathscsv.shape,sanitationcsv.shape

infdeathscsv.merge(sanitationcsv).shape
# Out:
# (1001, 5)

# %%
infdeaths_sanitation=infdeathscsv.merge(sanitationcsv)

infdeaths_sanitation.shape,humrightscsv.shape
# Out:
# ((1001, 5), (930, 3))

# %%
merged=infdeaths_sanitation.merge(humrightscsv)

merged.info()

merged.head()

merged

merged
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 860 entries, 0 to 859
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   country     860 non-null    object
#  1   year        860 non-null    int64
#  2   death rate  860 non-null    float64
#  3   ldw         852 non-null    float64
#  4   lss         853 non-null    float64
#  5   vdem        860 non-null    float64
# dtypes: float64(4), int64(1), object(1)
# memory usage: 47.0+ KB
#          country  year  death rate    ldw    lss   vdem
# 0    Afghanistan  2015      164.90   3.51   9.73  0.555
# 1    Afghanistan  2016      158.93   3.16   9.95  0.513
# 2    Afghanistan  2017      152.43   2.78  10.18  0.545
# 3    Afghanistan  2018      146.83   2.36  10.39  0.557
# 4    Afghanistan  2019      140.37   1.91  10.60  0.516
# ..           ...   ...         ...    ...    ...    ...
# 855     Zimbabwe  2015      689.64  12.46  26.87  0.429
# 856     Zimbabwe  2016      651.67  12.82  27.52  0.389
# 857     Zimbabwe  2017      614.94  13.17  28.18  0.434
# 858     Zimbabwe  2018      576.06  13.52  28.85  0.428
# 859     Zimbabwe  2019      551.65  13.86  29.54  0.391
#
# [860 rows x 6 columns]

# %%
merged.to_csv("mergeddeliverable2.csv", index=False)
